# %% [markdown]
# <a href="https://colab.research.google.com/github/NecipOz/Dvpython/blob/main/DV_capstone_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to **"Bike Demand Visualization Project"** which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#
# The aim of this project is to reveal the current patterns in the data by showing the historical data of London bike shares with visualization tools.
#
# This will allow us to X-ray the data as part of the EDA process before setting up a machine learning model.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
#
#
#
# #### Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# **"weather_code" category description:**
# * 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# * 2 = scattered clouds / few clouds
# * 3 = Broken clouds
# * 4 = Cloudy
# * 7 = Rain/ light Rain shower/ Light rain
# * 10 = rain with thunderstorm
# * 26 = snowfall
# * 94 = Freezing Fog
# ---
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc.  Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.

# %% [markdown]
# # Tasks

# %% [markdown]
# ### 1.Import libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.Read dataset

# %%
df = pd.read_csv("store_sharing.csv")

# %%
df.head()
# Out:
#             timestamp  cnt   t1   t2  ...  month  day_of_month  day_of_week  hour
# 0 2015-01-04 00:00:00  182  3.0  2.0  ...      1             4            6     0
# 1 2015-01-04 01:00:00  138  3.0  2.5  ...      1             4            6     1
# 2 2015-01-04 02:00:00  134  2.5  2.5  ...      1             4            6     2
# 3 2015-01-04 03:00:00   72  2.0  2.0  ...      1             4            6     3
# 4 2015-01-04 04:00:00   47  2.0  0.0  ...      1             4            6     4
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# ### 3.Check missing values and if there are any dublicate rows or not.

# %%
df.isnull().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %% [markdown]
# ### 4.Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)

# %%
sns.barplot(x=df.season.value_counts().index, 
            y=df.season.value_counts(), 
            data=df)
plt.xlabel("season")
plt.ylabel("count")
plt.show()

# %%
# season

# %%
sns.barplot(x=df.is_holiday.value_counts().index, 
            y=df.is_holiday.value_counts(), 
            data=df)
plt.xlabel("is_holiday")
plt.ylabel("count")
plt.show()

# %%
# is_holiday

# %%
sns.barplot(x=df.is_weekend.value_counts().index, 
            y=df.is_weekend.value_counts(), 
            data=df)
plt.xlabel("is_weekend")
plt.ylabel("count")
plt.show()

# %%
# is_weekend

# %%
sns.barplot(x=df.weather_code.value_counts().index, 
            y=df.weather_code.value_counts(), 
            data=df)
plt.xlabel("weather_code")
plt.ylabel("count")
plt.show()

# %%
# weather_code

# %% [markdown]
# ### 5.Look at the data type of each variable, transform `timestamp` in type, and set it as index.

# %%
type(df.timestamp[0])
# Out:
# str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df["timestamp"] = pd.to_datetime(df.timestamp)
df.timestamp
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %%
df["year_month"] = df.timestamp.dt.strftime('%Y-%m')
df['year'] = df.timestamp.dt.year
df['month'] = df.timestamp.dt.month
df['day_of_month'] = df.timestamp.dt.day
df['day_of_week'] = df.timestamp.dt.day_of_week
df['hour'] = df.timestamp.dt.hour

# %%
# Out:
#                      cnt   t1   t2  ...  is_holiday  is_weekend  season
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 01:00:00  138  3.0  2.5  ...         0.0         1.0     3.0
# 2015-01-04 02:00:00  134  2.5  2.5  ...         0.0         1.0     3.0
# 2015-01-04 03:00:00   72  2.0  2.0  ...         0.0         1.0     3.0
# 2015-01-04 04:00:00   47  2.0  0.0  ...         0.0         1.0     3.0
#
# [5 rows x 9 columns]

# %% [markdown]
# - Tam 2 yillik bir timestamp var. `year, month, day_of_month, day_of_week, hour` bilgilerini alarak feature engineering yapalim

# %% [markdown]
# ### 6.Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %% [markdown]
# you can use strftime('%Y-%m') for year_mount

# %%
df.head()
# Out:
#             timestamp  cnt   t1   t2  ...  month  day_of_month  day_of_week  hour
# 0 2015-01-04 00:00:00  182  3.0  2.0  ...      1             4            6     0
# 1 2015-01-04 01:00:00  138  3.0  2.5  ...      1             4            6     1
# 2 2015-01-04 02:00:00  134  2.5  2.5  ...      1             4            6     2
# 3 2015-01-04 03:00:00   72  2.0  2.0  ...      1             4            6     3
# 4 2015-01-04 04:00:00   47  2.0  0.0  ...      1             4            6     4
#
# [5 rows x 16 columns]

# %%
df.head()
# Out:
#                      cnt   t1   t2  ...  day_of_month  day_of_week  hour
# timestamp                           ...
# 2015-01-04 00:00:00  182  3.0  2.0  ...             4            6     0
# 2015-01-04 01:00:00  138  3.0  2.5  ...             4            6     1
# 2015-01-04 02:00:00  134  2.5  2.5  ...             4            6     2
# 2015-01-04 03:00:00   72  2.0  2.0  ...             4            6     3
# 2015-01-04 04:00:00   47  2.0  0.0  ...             4            6     4
#
# [5 rows x 15 columns]

# %% [markdown]
# ### 7.Visualize the correlation with a heatmap

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.corr(), cmap='coolwarm', annot=True);

# %%
# for all variables

# %%
plt.figure(figsize=(2,7))
sns.heatmap(df.corr()[["cnt"]], cmap='BrBG', vmin=-1, vmax=1, annot=True);

# %%
# for the target variable

# %% [markdown]
# ### 8. Visualize the correlation of the target variable and the other features with barplot

# %%
df.corr()["cnt"].sort_values()
# Out:
# hum            -0.462901
# weather_code   -0.166633
# season         -0.116180
# is_weekend     -0.096499
# day_of_week    -0.068688
# is_holiday     -0.051698
# day_of_month   -0.017887
# year            0.010046
# month           0.063757
# wind_speed      0.116295
# hour            0.324423
# t2              0.369035
# t1              0.388798
# cnt             1.000000
# Name: cnt, dtype: float64

# %%
corr_cnt = df.corr()["cnt"].sort_values()
index_y = df.corr()["cnt"].sort_values().index
plt.figure(figsize=(10,6))
plt.hlines(y=index_y, xmin=0,xmax=corr_cnt,alpha=0.7, linewidth=10, color="blue")
plt.show()

# %%
#with pandas

# %% [markdown]
# ### 9.Plot bike shares over time use lineplot

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="timestamp", y="cnt", data=df);

# %% [markdown]
# ### 10.Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x="year_month", y="cnt", data=df, err_style=None)
locs, labels = plt.xticks()
plt.setp(labels, rotation=90);

# %%
# with lineplot

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="month", y="cnt", data=df);

# %%
# with lineplot

# %%
plt.figure(figsize=(15,5))
sns.pointplot(x="month", y="cnt", data=df);

# %%
# with pointplot

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="month", y="cnt", data=df);

# %%
# with barplot

# %% [markdown]
# ### 11.Plot bike shares by hours on (holidays, weekend, season)

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x="hour", y="cnt", hue="is_holiday", data=df);

# %%
# with lineplot (*whether it is a holiday or not*)

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="hour", y="cnt", hue="season", data=df);

# %%
# with lineplot (*You may want to see seasonal breakdowns*)

# %%
plt.figure(figsize=(18,16))
plt.subplot(4, 1, 1)
sns.pointplot(x="hour", y="cnt", data=df)
plt.subplot(4, 1, 2)
sns.pointplot(x="hour", y="cnt", hue="is_holiday", data=df)
plt.subplot(4, 1, 3)
sns.pointplot(x="hour", y="cnt", hue="is_weekend", data=df)
plt.subplot(4, 1, 4)
sns.pointplot(x="hour", y="cnt", hue="season", data=df);

# %%
# with pointplot

# %% [markdown]
# ### 12.Plot bike shares by day of week
# - You may want to see whether it is a holiday or not

# %%
sns.barplot(x="day_of_week", y="cnt", hue="is_weekend", data=df);

# %%
# with barplot

# %%
plt.figure(figsize=(16,8))
plt.subplot(2, 1, 1)
sns.pointplot(x="day_of_week", y="cnt", data=df)
plt.subplot(2, 1, 2)
sns.pointplot(x="day_of_week", y="cnt", hue="season", data=df);

# %%
# with pointplot

# %% [markdown]
# ### 13.Plot bike shares by day of month

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x="day_of_month", y="cnt", data=df);

# %%
#with lineplot
# Out:
# day_of_month    1     2     3     4     5   ...    27    28    29    30   31
# cnt           1077  1088  1128  1144  1141  ...  1131  1063  1080  1156  968
#
# [1 rows x 31 columns]

# %% [markdown]
# ### 14.Plot bike shares by year
# ### Plot bike shares on holidays by seasons

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="year", y="cnt", data=df);

# %%
# with barplot

# %%
plt.figure()
sns.barplot(x="season", y="cnt", data=df, estimator=np.max);

# %%
# with barplot

# %% [markdown]
# ### 15.Visualize the distribution of bike shares by weekday/weekend with piechart and barplot

# %%
plt.figure(figsize=(5,5))
my_labels= ["weekday","weekend"]
y = df["is_weekend"].value_counts()
plt.pie(y, labels=my_labels, autopct="%.1f");

# %%
# pie chart

# %%
plt.figure(figsize=(7,5))
sns.countplot(x="is_weekend", data=df)
a=df["is_weekend"].value_counts()

plt.text(0,a[0]+25, f"%{round((a[0]*100)/(a[1]+a[0]),1)} - {a[0]}", ha="center", fontsize=12)
plt.text(1,a[1]+25, f"%{round((a[1]*100)/(a[1]+a[0]),1)} - {a[1]}", ha="center", fontsize=12);

# %%
# with countplot

# %% [markdown]
# ### 16.Plot the distribution of weather code by seasons

# %%
sns.countplot(x="weather_code", data=df);

# %%
# with countplot

# %%
sns.catplot(x="weather_code", data=df, col="season", col_wrap=4, kind="count");

# %%
# with catplot

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
